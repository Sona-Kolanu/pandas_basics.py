# %% [markdown]
# <a href="https://colab.research.google.com/github/Sona-Kolanu/pandas_basics.py/blob/main/pandas_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
s=pd.Series([1,2,3,4,5])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data={
    'Name':['Sona','Aishwarya','Sai',"Uma","Ramesh","Ravi","Raju","Teju","Vani","Suhana"],
    'Age':[22,23,20,18,22,25,24,16,19,17],
    'marks':[3,43,31,45,75,34,76,98,43,22],
    'Grades':["A","A","C","D","B","A","C","B","D","C"]
}
df=pd.DataFrame(data)
print(df)
# Out:
#         Name  Age  marks Grades
# 0       Sona   22      3      A
# 1  Aishwarya   23     43      A
# 2        Sai   20     31      C
# 3        Uma   18     45      D
# 4     Ramesh   22     75      B
# 5       Ravi   25     34      A
# 6       Raju   24     76      C
# 7       Teju   16     98      B
# 8       Vani   19     43      D
# 9     Suhana   17     22      C

# %%
df.loc[1,'Name']="icuu"
df.to_csv("Sample.csv",index=False)
c=pd.read_csv("Sample.csv")
print(c)
# Out:
#      Name  Age  marks Grades
# 0    Sona   22      3      A
# 1    icuu   23     43      A
# 2     Sai   20     31      C
# 3     Uma   18     45      D
# 4  Ramesh   22     75      B
# 5    Ravi   25     34      A
# 6    Raju   24     76      C
# 7    Teju   16     98      B
# 8    Vani   19     43      D
# 9  Suhana   17     22      C

# %%
df.head()
# Out:
#      Name  Age  marks Grades
# 0    Sona   22      3      A
# 1    icuu   23     43      A
# 2     Sai   20     31      C
# 3     Uma   18     45      D
# 4  Ramesh   22     75      B

# %%
df.tail()
# Out:
#      Name  Age  marks Grades
# 5    Ravi   25     34      A
# 6    Raju   24     76      C
# 7    Teju   16     98      B
# 8    Vani   19     43      D
# 9  Suhana   17     22      C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Age     10 non-null     int64
#  2   marks   10 non-null     int64
#  3   Grades  10 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 452.0+ bytes

# %%
df.describe()
# Out:
#              Age      marks
# count  10.000000  10.000000
# mean   20.600000  47.000000
# std     3.062316  28.378396
# min    16.000000   3.000000
# 25%    18.250000  31.750000
# 50%    21.000000  43.000000
# 75%    22.750000  67.500000
# max    25.000000  98.000000
